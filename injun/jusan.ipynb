# %%
import numpy as np
import pandas as pd
import sys
import tensorflow as tf  #tensorflow-2.16.
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import cv2
# %matplotlib inline


img_1 = cv2.imread('/content/jusan_oneshot.png', cv2.IMREAD_COLOR) # 이미지를 [B, G, R] 순의 numpy 객체로 반환
img_gray = cv2.cvtColor(img_1, cv2.COLOR_BGR2GRAY) # 흑백으로 변환

plt.imshow(img_gray, cmap='gray')
plt.show()
